# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/jayasuryarathinagiri/Desktop/DATA ANALYST/Companies.csv')
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
pd.set_option('display.max.row', 100)

# %%
df[df['Rank']<=10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# ...

# %%
specific_store = ['Apple', 'Walmart']
df[df['Name'].isin(specific_store)]
# Out:
#    Rank     Name              Industry Revenue (USD millions) Revenue growth  \
# 0     1  Walmart                Retail                611,289           6.7%
# 3     4    Apple  Electronics industry                394,328           7.8%
#
#    Employees           Headquarters
# 0  2,100,000  Bentonville, Arkansas
# 3    164,000  Cupertino, California

# %%
df[df['Name'].str.contains('Apple')]
# Out:
#    Rank   Name              Industry Revenue (USD millions) Revenue growth  \
# 3     4  Apple  Electronics industry                394,328           7.8%
#
#   Employees           Headquarters
# 3   164,000  Cupertino, California

# %%
df.tail(10)
# Out:
#     Rank                      Name                 Industry  \
# 90    91         American Airlines                  Airline
# 91    92                       CHS  Agriculture cooperative
# 92    93    Performance Food Group          Food processing
# 93    94                PBF Energy       Petroleum industry
# 94    95                      Nike                  Apparel
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology
#
#    Revenue (USD millions) Revenue growth Employees  \
# 90                 48,971          63.9%   129,700
# 91                 47,194          24.3%    10,014
# 92                 47,194          61.6%    34,825
# 93                 46,830          71.8%     3,616
# ...

# %%
df2 = df
df2.filter(items = ['Name','Revenue (USD millions)'], axis = 1)
# Out:
#                                    Name Revenue (USD millions)
# 0                               Walmart                611,289
# 1                                Amazon                513,983
# 2                            ExxonMobil                413,680
# 3                                 Apple                394,328
# 4                    UnitedHealth Group                324,162
# 5                            CVS Health                322,467
# 6                    Berkshire Hathaway                302,089
# 7                              Alphabet                282,836
# 8                  McKesson Corporation                276,711
# 9                   Chevron Corporation                246,252
# 10                              Cencora                238,587
# 11                               Costco                226,954
# 12                            Microsoft                198,270
# 13                      Cardinal Health                181,364
# ...

# %%
df[df['Headquarters'].str.contains('Chicago, Illinois')]
# Out:
#     Rank                    Name       Industry Revenue (USD millions)  \
# 34    35  Archer Daniels Midland  Food industry                101,556
# 97    98         United Airlines        Airline                 44,955
#
#    Revenue growth Employees       Headquarters
# 34          19.1%    41,181  Chicago, Illinois
# 97          82.5%    92,795  Chicago, Illinois
